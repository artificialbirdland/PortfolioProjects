# %%
#Import Libraries
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) #Adjusts the configurations plots we will create

# %%
#Read in the data
df = pd.read_csv(r'C:\Users\Enes\Desktop\movies.csv')

# %%
#Let's look at the data
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime
# 0   46998772.0        Warner Bros.    146.0
# 1   58853106.0   Columbia Pictures    104.0
# 2  538375067.0           Lucasfilm    124.0
# 3   83453539.0  Paramount Pictures     88.0
# 4   39846344.0      Orion Pictures     98.0

# %%
#Let's see if there is any missing data
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col,pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
#Data types for our columns

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df['budget'] = df['budget'].fillna(0).astype('int64')
df['gross'] = df['gross'].fillna(0).astype('int64')

# %%
# Create correct year column
df['yearcorrect'] = df['released'].str.extract(r',\s*(.*?)\s*\(', expand=False)
# Change the data type 
df['yearcorrect'] = df['yearcorrect'].fillna(0).astype('int64')

# %%
df.sort_values(by = ['gross'], inplace =False, ascending = False)
# Out:
#                                             name rating    genre  year  \
# 5445                                      Avatar  PG-13   Action  2009
# 7445                           Avengers: Endgame  PG-13   Action  2019
# 3045                                     Titanic  PG-13    Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13   Action  2015
# 7244                      Avengers: Infinity War  PG-13   Action  2018
# ...                                          ...    ...      ...   ...
# 1617                             Mortal Passions      R    Crime  1989
# 1614                              Edge of Sanity      R   Horror  1989
# 1606                                   I, Madman      R  Fantasy  1989
# 1601                        My Twentieth Century    NaN   Comedy  1989
# 7667                                   Tee em el    NaN   Horror  2020
#
#                                released  score      votes        director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0   James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0   Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0   James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0     J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0   Anthony Russo
# ...                                 ...    ...        ...             ...
# 1617   January 26, 1990 (United States)    4.5      274.0     Andrew Lane
# 1614     April 14, 1989 (United States)    5.2     1300.0  Gérard Kikoïne
# 1606      April 7, 1989 (United States)    6.0     2900.0    Tibor Takács
# 1601           January 13, 1990 (Japan)    7.1     1500.0   Ildikó Enyedi
# 7667    August 19, 2020 (United States)    5.7        7.0    Pereko Mosia
#
#                   writer               star         country     budget  \
# 5445       James Cameron    Sam Worthington   United States  237000000
# 7445  Christopher Markus  Robert Downey Jr.   United States  356000000
# 3045       James Cameron  Leonardo DiCaprio   United States  200000000
# 6663     Lawrence Kasdan       Daisy Ridley   United States  245000000
# 7244  Christopher Markus  Robert Downey Jr.   United States  321000000
# ...                  ...                ...             ...        ...
# 1617      Alan Moskowitz      Zach Galligan   United States          0
# 1614          J.P. Félix    Anthony Perkins  United Kingdom          0
# 1606       David Chaskin       Jenny Wright          Canada          0
# 1601       Ildikó Enyedi       Dorota Segda         Hungary          0
# 7667        Pereko Mosia   Siyabonga Mabaso    South Africa          0
#
#            gross                          company  runtime  yearcorrect
# 5445  2847246203            Twentieth Century Fox    162.0         2009
# 7445  2797501328                   Marvel Studios    181.0         2019
# 3045  2201647264            Twentieth Century Fox    194.0         1997
# 6663  2069521700                        Lucasfilm    138.0         2015
# 7244  2048359754                   Marvel Studios    149.0         2018
# ...          ...                              ...      ...          ...
# 1617           0          Gibraltar Entertainment     92.0         1990
# 1614           0                    Allied Vision     85.0         1989
# 1606           0  Trans World Entertainment (TWE)     89.0         1989
# 1601           0         Budapest Stúdió Vállalat    104.0         1990
# 7667           0                      PK 65 Films    102.0         2020
#
# [7668 rows x 16 columns]

# %%
# Drop any duplicates
df['company'].drop_duplicates().sort_values(ascending=False)
df.drop_duplicates()
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
#                               released  score      votes         director  \
# 0        June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1         July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2        June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3         July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4        July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
# ...                                ...    ...        ...              ...
# 7663  October 23, 2020 (United States)    3.1       18.0    Joseph Ebanks
# 7664  February 7, 2020 (United States)    4.7       36.0     Dusty Dukatz
# 7665         April 27, 2020 (Cameroon)    5.7       29.0     Nkanya Nkwai
# 7666   October 1, 2020 (United States)    NaN        NaN    James Randall
# 7667   August 19, 2020 (United States)    5.7        7.0     Pereko Mosia
#
#                        writer              star         country    budget  \
# 0                Stephen King    Jack Nicholson  United Kingdom  19000000
# 1     Henry De Vere Stacpoole    Brooke Shields   United States   4500000
# 2              Leigh Brackett       Mark Hamill   United States  18000000
# 3                Jim Abrahams       Robert Hays   United States   3500000
# 4          Brian Doyle-Murray       Chevy Chase   United States   6000000
# ...                       ...               ...             ...       ...
# 7663            Joseph Ebanks      Shannon Bond   United States      7000
# 7664              Lisa Huston  Michael Saquella   United States         0
# 7665             Lynno Lovert      Onyama Laura   United States     58750
# 7666            James Randall     Christina Roz   United States     15000
# 7667             Pereko Mosia  Siyabonga Mabaso    South Africa         0
#
#           gross                    company  runtime  yearcorrect
# 0      46998772               Warner Bros.    146.0         1980
# 1      58853106          Columbia Pictures    104.0         1980
# 2     538375067                  Lucasfilm    124.0         1980
# 3      83453539         Paramount Pictures     88.0         1980
# 4      39846344             Orion Pictures     98.0         1980
# ...         ...                        ...      ...          ...
# 7663          0                        NaN     90.0         2020
# 7664          0  Cactus Blue Entertainment     90.0         2020
# 7665          0           Embi Productions      NaN         2020
# 7666          0                        NaN    120.0         2020
# 7667          0                PK 65 Films    102.0         2020
#
# [7668 rows x 16 columns]

# %%
# Testing a correlation

# %%
# Scatter plot with budget vs gross

plt.scatter(x = df['budget'], y = df['gross'])

plt.title('Budget vs Gross Earnings')

plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')

plt.show()

# %%
df.sort_values(by = ['gross'], inplace =False, ascending = False)
# Out:
#                                             name rating    genre  year  \
# 5445                                      Avatar  PG-13   Action  2009
# 7445                           Avengers: Endgame  PG-13   Action  2019
# 3045                                     Titanic  PG-13    Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13   Action  2015
# 7244                      Avengers: Infinity War  PG-13   Action  2018
# ...                                          ...    ...      ...   ...
# 1617                             Mortal Passions      R    Crime  1989
# 1614                              Edge of Sanity      R   Horror  1989
# 1606                                   I, Madman      R  Fantasy  1989
# 1601                        My Twentieth Century    NaN   Comedy  1989
# 7667                                   Tee em el    NaN   Horror  2020
#
#                                released  score      votes        director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0   James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0   Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0   James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0     J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0   Anthony Russo
# ...                                 ...    ...        ...             ...
# 1617   January 26, 1990 (United States)    4.5      274.0     Andrew Lane
# 1614     April 14, 1989 (United States)    5.2     1300.0  Gérard Kikoïne
# 1606      April 7, 1989 (United States)    6.0     2900.0    Tibor Takács
# 1601           January 13, 1990 (Japan)    7.1     1500.0   Ildikó Enyedi
# 7667    August 19, 2020 (United States)    5.7        7.0    Pereko Mosia
#
#                   writer               star         country     budget  \
# 5445       James Cameron    Sam Worthington   United States  237000000
# 7445  Christopher Markus  Robert Downey Jr.   United States  356000000
# 3045       James Cameron  Leonardo DiCaprio   United States  200000000
# 6663     Lawrence Kasdan       Daisy Ridley   United States  245000000
# 7244  Christopher Markus  Robert Downey Jr.   United States  321000000
# ...                  ...                ...             ...        ...
# 1617      Alan Moskowitz      Zach Galligan   United States          0
# 1614          J.P. Félix    Anthony Perkins  United Kingdom          0
# 1606       David Chaskin       Jenny Wright          Canada          0
# 1601       Ildikó Enyedi       Dorota Segda         Hungary          0
# 7667        Pereko Mosia   Siyabonga Mabaso    South Africa          0
#
#            gross                          company  runtime  yearcorrect
# 5445  2847246203            Twentieth Century Fox    162.0         2009
# 7445  2797501328                   Marvel Studios    181.0         2019
# 3045  2201647264            Twentieth Century Fox    194.0         1997
# 6663  2069521700                        Lucasfilm    138.0         2015
# 7244  2048359754                   Marvel Studios    149.0         2018
# ...          ...                              ...      ...          ...
# 1617           0          Gibraltar Entertainment     92.0         1990
# 1614           0                    Allied Vision     85.0         1989
# 1606           0  Trans World Entertainment (TWE)     89.0         1989
# 1601           0         Budapest Stúdió Vállalat    104.0         1990
# 7667           0                      PK 65 Films    102.0         2020
#
# [7668 rows x 16 columns]

# %%
# Plot Budget vs Gross using seaborn

sns.regplot(x = 'budget', y = 'gross',data = df, scatter_kws= {"color":"red"}, line_kws={"color":"green"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
# Let's start looking at correlation

# %%
numeric_df = df.select_dtypes(include=['number'])
correlation_matrix = numeric_df.corr(method = 'pearson')
correlation_matrix
# Out:
#                  year     score     votes    budget     gross   runtime  \
# year         1.000000  0.097995  0.222945  0.309212  0.261900  0.120811
# score        0.097995  1.000000  0.409182  0.055665  0.186392  0.399451
# votes        0.222945  0.409182  1.000000  0.486862  0.632834  0.309212
# budget       0.309212  0.055665  0.486862  1.000000  0.750157  0.269510
# gross        0.261900  0.186392  0.632834  0.750157  1.000000  0.245235
# runtime      0.120811  0.399451  0.309212  0.269510  0.245235  1.000000
# yearcorrect  0.143738  0.001653  0.056070  0.073969  0.056556  0.027707
#
#              yearcorrect
# year            0.143738
# score           0.001653
# votes           0.056070
# budget          0.073969
# gross           0.056556
# runtime         0.027707
# yearcorrect     1.000000

# %%
sns.heatmap(correlation_matrix, annot = True)

plt.title('Correlation Matric for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
# Looks at Company
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000
# 2           Leigh Brackett     Mark Hamill   United States  18000000
# 3             Jim Abrahams     Robert Hays   United States   3500000
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000
#
#        gross             company  runtime  yearcorrect
# 0   46998772        Warner Bros.    146.0         1980
# 1   58853106   Columbia Pictures    104.0         1980
# 2  538375067           Lucasfilm    124.0         1980
# 3   83453539  Paramount Pictures     88.0         1980
# 4   39846344      Orion Pictures     98.0         1980

# %%
df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1     5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2     5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3      286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4     1027       6      4  1980      1543    7.3   108000.0      1054     521
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7663  3705      -1      6  2020      2964    3.1       18.0      1500    2289
# 7664  1678      -1      4  2020      1107    4.7       36.0       774    2614
# 7665  4717      -1      6  2020       193    5.7       29.0      2061    2683
# 7666  2843      -1      6  2020      2817    NaN        NaN      1184    1824
# 7667  5394      -1     10  2020       391    5.7        7.0      2165    3344
#
#       star  country    budget      gross  company  runtime  yearcorrect
# 0     1047       54  19000000   46998772     2319    146.0         1980
# 1      327       55   4500000   58853106      731    104.0         1980
# 2     1745       55  18000000  538375067     1540    124.0         1980
# 3     2246       55   3500000   83453539     1812     88.0         1980
# 4      410       55   6000000   39846344     1777     98.0         1980
# ...    ...      ...       ...        ...      ...      ...          ...
# 7663  2421       55      7000          0       -1     90.0         2020
# 7664  1886       55         0          0      539     90.0         2020
# 7665  2040       55     58750          0      941      NaN         2020
# 7666   450       55     15000          0       -1    120.0         2020
# 7667  2463       44         0          0     1787    102.0         2020
#
# [7668 rows x 16 columns]

# %%
df_numerized.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country    budget      gross  company  runtime  yearcorrect
# 0  1047       54  19000000   46998772     2319    146.0         1980
# 1   327       55   4500000   58853106      731    104.0         1980
# 2  1745       55  18000000  538375067     1540    124.0         1980
# 3  2246       55   3500000   83453539     1812     88.0         1980
# 4   410       55   6000000   39846344     1777     98.0         1980

# %%
correlation_matrix = df_numerized.corr(method = 'pearson')
sns.heatmap(correlation_matrix, annot = True)

plt.title('Correlation Matric for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

correlation_mat = df_numerized.corr()
corr_pairs = correlation_mat.unstack()
corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.008069
#              genre          0.016355
#              year           0.011453
#              released      -0.011311
#              score          0.017097
#              votes          0.013088
#              director       0.009079
#              writer         0.009081
#              star           0.006472
#              country       -0.010737
#              budget         0.020548
#              gross          0.006989
#              company        0.009211
#              runtime        0.010392
#              yearcorrect   -0.009264
# rating       name          -0.008069
#              rating         1.000000
#              genre          0.072423
#              year           0.008779
#              released       0.016613
#              score         -0.001314
#              votes          0.033225
#              director       0.019483
#              writer        -0.005921
#              star           0.013405
#              country        0.081244
#              budget        -0.081939
#              gross         -0.095450
#              company       -0.032943
#              runtime        0.062145
#              yearcorrect   -0.013129
# genre        name           0.016355
#              rating         0.072423
#              genre          1.000000
#              year          -0.081261
#              released       0.029822
#              score          0.027965
#              votes         -0.145307
#              director      -0.015258
#              writer         0.006567
#              star          -0.005477
#              country       -0.037615
#              budget        -0.334021
#              gross         -0.234297
#              company       -0.071067
#              runtime       -0.052711
#              yearcorrect   -0.061689
# year         name           0.011453
#              rating         0.008779
#              genre         -0.081261
#              year           1.000000
#              released      -0.000695
#              score          0.097995
#              votes          0.222945
#              director      -0.020795
#              writer        -0.008656
#              star          -0.027242
#              country       -0.070938
#              budget         0.309212
#              gross          0.261900
#              company       -0.010431
#              runtime        0.120811
#              yearcorrect    0.143738
# released     name          -0.011311
#              rating         0.016613
#              genre          0.029822
#              year          -0.000695
#              released       1.000000
#              score          0.042788
#              votes          0.016097
#              director      -0.001478
#              writer        -0.002404
#              star           0.015777
#              country       -0.020427
#              budget         0.009145
#              gross          0.000519
#              company       -0.010474
#              runtime        0.000868
#              yearcorrect    0.026875
# score        name           0.017097
#              rating        -0.001314
#              genre          0.027965
#              year           0.097995
#              released       0.042788
#              score          1.000000
#              votes          0.409182
#              director       0.009559
#              writer         0.019416
#              star          -0.001609
#              country       -0.133348
#              budget         0.055665
#              gross          0.186392
#              company        0.001030
#              runtime        0.399451
#              yearcorrect    0.001653
# votes        name           0.013088
#              rating         0.033225
#              genre         -0.145307
#              year           0.222945
#              released       0.016097
#              score          0.409182
#              votes          1.000000
#              director       0.000260
#              writer         0.000892
#              star          -0.019282
#              country        0.073625
#              budget         0.486862
#              gross          0.632834
#              company        0.133204
#              runtime        0.309212
#              yearcorrect    0.056070
# director     name           0.009079
#              rating         0.019483
#              genre         -0.015258
#              year          -0.020795
#              released      -0.001478
#              score          0.009559
#              votes          0.000260
#              director       1.000000
#              writer         0.299067
#              star           0.039234
#              country        0.017490
#              budget         0.004976
#              gross         -0.014916
#              company        0.004404
#              runtime        0.017624
#              yearcorrect    0.010682
# writer       name           0.009081
#              rating        -0.005921
#              genre          0.006567
#              year          -0.008656
#              released      -0.002404
#              score          0.019416
#              votes          0.000892
#              director       0.299067
#              writer         1.000000
#              star           0.027245
#              country        0.015343
#              budget        -0.025911
#              gross         -0.022997
#              company        0.005646
#              runtime       -0.003511
#              yearcorrect    0.011463
# star         name           0.006472
#              rating         0.013405
#              genre         -0.005477
#              year          -0.027242
#              released       0.015777
#              score         -0.001609
#              votes         -0.019282
#              director       0.039234
#              writer         0.027245
#              star           1.000000
#              country       -0.012998
#              budget        -0.019952
#              gross         -0.001129
#              company        0.012442
#              runtime        0.010174
#              yearcorrect    0.016025
# country      name          -0.010737
#              rating         0.081244
#              genre         -0.037615
#              year          -0.070938
#              released      -0.020427
#              score         -0.133348
#              votes          0.073625
#              director       0.017490
#              writer         0.015343
#              star          -0.012998
#              country        1.000000
#              budget         0.131720
#              gross          0.095325
#              company        0.095548
#              runtime       -0.078412
#              yearcorrect    0.045654
# budget       name           0.020548
#              rating        -0.081939
#              genre         -0.334021
#              year           0.309212
#              released       0.009145
#              score          0.055665
#              votes          0.486862
#              director       0.004976
#              writer        -0.025911
#              star          -0.019952
#              country        0.131720
#              budget         1.000000
#              gross          0.750157
#              company        0.186474
#              runtime        0.269510
#              yearcorrect    0.073969
# gross        name           0.006989
#              rating        -0.095450
#              genre         -0.234297
#              year           0.261900
#              released       0.000519
#              score          0.186392
#              votes          0.632834
#              director      -0.014916
#              writer        -0.022997
#              star          -0.001129
#              country        0.095325
#              budget         0.750157
#              gross          1.000000
#              company        0.156745
#              runtime        0.245235
#              yearcorrect    0.056556
# company      name           0.009211
#              rating        -0.032943
#              genre         -0.071067
#              year          -0.010431
#              released      -0.010474
#              score          0.001030
#              votes          0.133204
#              director       0.004404
#              writer         0.005646
#              star           0.012442
#              country        0.095548
#              budget         0.186474
#              gross          0.156745
#              company        1.000000
#              runtime        0.034402
#              yearcorrect    0.051730
# runtime      name           0.010392
#              rating         0.062145
#              genre         -0.052711
#              year           0.120811
#              released       0.000868
#              score          0.399451
#              votes          0.309212
#              director       0.017624
#              writer        -0.003511
#              star           0.010174
#              country       -0.078412
#              budget         0.269510
#              gross          0.245235
#              company        0.034402
#              runtime        1.000000
#              yearcorrect    0.027707
# yearcorrect  name          -0.009264
#              rating        -0.013129
#              genre         -0.061689
#              year           0.143738
#              released       0.026875
#              score          0.001653
#              votes          0.056070
#              director       0.010682
#              writer         0.011463
#              star           0.016025
#              country        0.045654
#              budget         0.073969
#              gross          0.056556
#              company        0.051730
#              runtime        0.027707
#              yearcorrect    1.000000
# dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# budget       genre         -0.334021
# genre        budget        -0.334021
# gross        genre         -0.234297
# genre        gross         -0.234297
# votes        genre         -0.145307
# genre        votes         -0.145307
# country      score         -0.133348
# score        country       -0.133348
# gross        rating        -0.095450
# rating       gross         -0.095450
# budget       rating        -0.081939
# rating       budget        -0.081939
# year         genre         -0.081261
# genre        year          -0.081261
# country      runtime       -0.078412
# runtime      country       -0.078412
# company      genre         -0.071067
# genre        company       -0.071067
# country      year          -0.070938
# year         country       -0.070938
# yearcorrect  genre         -0.061689
# genre        yearcorrect   -0.061689
#              runtime       -0.052711
# runtime      genre         -0.052711
# country      genre         -0.037615
# genre        country       -0.037615
# rating       company       -0.032943
# company      rating        -0.032943
# year         star          -0.027242
# star         year          -0.027242
# budget       writer        -0.025911
# writer       budget        -0.025911
# gross        writer        -0.022997
# writer       gross         -0.022997
# year         director      -0.020795
# director     year          -0.020795
# released     country       -0.020427
# country      released      -0.020427
# budget       star          -0.019952
# star         budget        -0.019952
#              votes         -0.019282
# votes        star          -0.019282
# genre        director      -0.015258
# director     genre         -0.015258
#              gross         -0.014916
# gross        director      -0.014916
# rating       yearcorrect   -0.013129
# yearcorrect  rating        -0.013129
# star         country       -0.012998
# country      star          -0.012998
# released     name          -0.011311
# name         released      -0.011311
#              country       -0.010737
# country      name          -0.010737
# released     company       -0.010474
# company      released      -0.010474
# year         company       -0.010431
# company      year          -0.010431
# name         yearcorrect   -0.009264
# yearcorrect  name          -0.009264
# year         writer        -0.008656
# writer       year          -0.008656
# name         rating        -0.008069
# rating       name          -0.008069
#              writer        -0.005921
# writer       rating        -0.005921
# genre        star          -0.005477
# star         genre         -0.005477
# runtime      writer        -0.003511
# writer       runtime       -0.003511
# released     writer        -0.002404
# writer       released      -0.002404
# star         score         -0.001609
# score        star          -0.001609
# director     released      -0.001478
# released     director      -0.001478
# score        rating        -0.001314
# rating       score         -0.001314
# gross        star          -0.001129
# star         gross         -0.001129
# year         released      -0.000695
# released     year          -0.000695
# votes        director       0.000260
# director     votes          0.000260
# released     gross          0.000519
# gross        released       0.000519
# runtime      released       0.000868
# released     runtime        0.000868
# writer       votes          0.000892
# votes        writer         0.000892
# company      score          0.001030
# score        company        0.001030
# yearcorrect  score          0.001653
# score        yearcorrect    0.001653
# company      director       0.004404
# director     company        0.004404
#              budget         0.004976
# budget       director       0.004976
# writer       company        0.005646
# company      writer         0.005646
# name         star           0.006472
# star         name           0.006472
# genre        writer         0.006567
# writer       genre          0.006567
# name         gross          0.006989
# gross        name           0.006989
# rating       year           0.008779
# year         rating         0.008779
# director     name           0.009079
# name         director       0.009079
#              writer         0.009081
# writer       name           0.009081
# budget       released       0.009145
# released     budget         0.009145
# company      name           0.009211
# name         company        0.009211
# director     score          0.009559
# score        director       0.009559
# runtime      star           0.010174
# star         runtime        0.010174
# runtime      name           0.010392
# name         runtime        0.010392
# director     yearcorrect    0.010682
# yearcorrect  director       0.010682
# year         name           0.011453
# name         year           0.011453
# writer       yearcorrect    0.011463
# yearcorrect  writer         0.011463
# company      star           0.012442
# star         company        0.012442
# name         votes          0.013088
# votes        name           0.013088
# rating       star           0.013405
# star         rating         0.013405
# country      writer         0.015343
# writer       country        0.015343
# star         released       0.015777
# released     star           0.015777
# star         yearcorrect    0.016025
# yearcorrect  star           0.016025
# votes        released       0.016097
# released     votes          0.016097
# name         genre          0.016355
# genre        name           0.016355
# rating       released       0.016613
# released     rating         0.016613
# name         score          0.017097
# score        name           0.017097
# director     country        0.017490
# country      director       0.017490
# director     runtime        0.017624
# runtime      director       0.017624
# writer       score          0.019416
# score        writer         0.019416
# director     rating         0.019483
# rating       director       0.019483
# budget       name           0.020548
# name         budget         0.020548
# yearcorrect  released       0.026875
# released     yearcorrect    0.026875
# star         writer         0.027245
# writer       star           0.027245
# yearcorrect  runtime        0.027707
# runtime      yearcorrect    0.027707
# score        genre          0.027965
# genre        score          0.027965
#              released       0.029822
# released     genre          0.029822
# votes        rating         0.033225
# rating       votes          0.033225
# company      runtime        0.034402
# runtime      company        0.034402
# director     star           0.039234
# star         director       0.039234
# score        released       0.042788
# released     score          0.042788
# country      yearcorrect    0.045654
# yearcorrect  country        0.045654
# company      yearcorrect    0.051730
# yearcorrect  company        0.051730
# score        budget         0.055665
# budget       score          0.055665
# yearcorrect  votes          0.056070
# votes        yearcorrect    0.056070
# yearcorrect  gross          0.056556
# gross        yearcorrect    0.056556
# runtime      rating         0.062145
# rating       runtime        0.062145
# genre        rating         0.072423
# rating       genre          0.072423
# votes        country        0.073625
# country      votes          0.073625
# budget       yearcorrect    0.073969
# yearcorrect  budget         0.073969
# country      rating         0.081244
# rating       country        0.081244
# country      gross          0.095325
# gross        country        0.095325
# company      country        0.095548
# country      company        0.095548
# year         score          0.097995
# score        year           0.097995
# year         runtime        0.120811
# runtime      year           0.120811
# country      budget         0.131720
# budget       country        0.131720
# company      votes          0.133204
# votes        company        0.133204
# yearcorrect  year           0.143738
# year         yearcorrect    0.143738
# company      gross          0.156745
# gross        company        0.156745
#              score          0.186392
# score        gross          0.186392
# company      budget         0.186474
# budget       company        0.186474
# votes        year           0.222945
# year         votes          0.222945
# runtime      gross          0.245235
# gross        runtime        0.245235
# year         gross          0.261900
# gross        year           0.261900
# runtime      budget         0.269510
# budget       runtime        0.269510
# director     writer         0.299067
# writer       director       0.299067
# budget       year           0.309212
# year         budget         0.309212
# votes        runtime        0.309212
# runtime      votes          0.309212
#              score          0.399451
# score        runtime        0.399451
# votes        score          0.409182
# score        votes          0.409182
# votes        budget         0.486862
# budget       votes          0.486862
# votes        gross          0.632834
# gross        votes          0.632834
# budget       gross          0.750157
# gross        budget         0.750157
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr
# Out:
# votes        gross          0.632834
# gross        votes          0.632834
# budget       gross          0.750157
# gross        budget         0.750157
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %%
# Votes and Budget have the highest correlation to gross earnings.
